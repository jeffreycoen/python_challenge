# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
gkey = "AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw"

# %%
# Import cities file into the cities_pd DataFrame
cities_df = pd.read_csv('Cities.csv')

cities_df = pd.DataFrame(cities_df)
cities_df.head(5)
# Out:
#            City         State
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating.
# Hint: Be sure to specify "" as the initial value for each column.
cities_df['lat'] = ''#np.arange(len(cities_df))
cities_df['lon'] = ''#np.arange(len(cities_df))
cities_df['airport_address'] = ''#np.arange(len(cities_df))
cities_df['rating'] = ''#np.arange(len(cities_df))

cities_df.head()
# Out:
#            City         State lat lon airport_address rating
# 0      New York      New York
# 1   Los Angeles    California
# 2       Chicago      Illinois
# 3       Houston         Texas
# 4  Philadelphia  Pennsylvania

# %%
# Loop through the cities_pd and get the lat/long for each city
# Hint: `requests.get(target_url).json()`
# Hint: `for index, row in cities_pd.iterrows():`
# Hint: `cities_pd.set_value()`

for index, row in cities_df.iterrows():
   # if row["City"] == 'New York':
        geocodeurl = "https://maps.googleapis.com/maps/api/geocode/json?address=" + row["City"] + ",+" + row["State"] + "&key="+gkey
        geo_data = requests.get(geocodeurl).json()
        cities_df.set_value(index, 'lat', str(geo_data["results"][0]["geometry"]["location"]["lat"]))
        cities_df.set_value(index, 'lon', str(geo_data["results"][0]["geometry"]["location"]["lng"]))
       # print(geocodeurl)
        
    
cities_df.head(5)
# Out:
#            City         State         lat           lon airport_address rating
# 0      New York      New York  40.7127837   -74.0059413
# 1   Los Angeles    California  34.0522342  -118.2436849
# 2       Chicago      Illinois  41.8781136   -87.6297982
# 3       Houston         Texas  29.7604267   -95.3698028
# 4  Philadelphia  Pennsylvania  39.9525839   -75.1652215

# %%
# Use the lat/lng we recovered to identify airports
# Hint: Code is similar to above block (i.e. you will need to use cities_pd.iterrows() again)
# Hint: Use the keyword search for "international+airport"
# Hint: Use a try-except to handle airports that are missing ratings

for index, row in cities_df.iterrows():
    target_type = "airport"
    airport_lat = row['lat']
    airport_lng = row['lon']

    # Build URL using the Google Maps API
    target_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=%s,%s&types=%s&radius=%s&key=%s" % (airport_lat, airport_lng, target_type, 8000, gkey)
    print(target_url)
    # Run request
    airport_add = requests.get(target_url).json()



# Print the name and address of the first bike shop to appear
    #cities_df.set_value(index, 'airport_address', str(geo_data["results"][0]["geometry"]["location"]["lat"]))
   # cities_df.set_value(index, 'lon', str(geo_data["results"][0]["geometry"]["location"]["lng"]))
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.7127837,-74.0059413&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=34.0522342,-118.2436849&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=41.8781136,-87.6297982&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=29.7604267,-95.3698028&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.9525839,-75.1652215&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.4483771,-112.0740373&types=airport&radius=8000&key=AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw
# ...

# %%
# Save Data to csv


# Visualize to confirm airport data appears
cities_df
# Out:
#                City                 State                lat  \
# 0          New York              New York         40.7127837
# 1       Los Angeles            California         34.0522342
# 2           Chicago              Illinois         41.8781136
# 3           Houston                 Texas         29.7604267
# 4      Philadelphia          Pennsylvania         39.9525839
# 5           Phoenix               Arizona         33.4483771
# 6       San Antonio                 Texas         29.4241219
# 7         San Diego            California          32.715738
# 8            Dallas                 Texas         32.7766642
# 9          San Jose            California         37.3382082
# 10           Austin                 Texas          30.267153
# 11     Jacksonville               Florida         30.3321838
# 12    San Francisco            California         37.7749295
# 13     Indianapolis               Indiana          39.768403
# ...
