# %% [markdown]
# # Miles Per Gallon
#
# There are many different features of a car that can help determine how many miles per gallon it has. In this activity, we will be creating a scatterplot to chart some of these relationships.
#
# * The scatterplot that we want to create will compare 'mpg' to 'horsepower'. A reference image can be found at the bottom of this notebook, but how we go about creating this chart is completely up to you!
#
#     * When reading in the data, there are 6 rows that are missing values in 'horsepower'. It is up to you to figure out what the author put in their place and drop the rows.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
car_data = pd.read_csv('MPG.csv')
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Remove the rows with missing values in horsepower
car_data = car_data.loc[car_data['horsepower'] != "?"]
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Set the 'car name' as our index
car_data = car_data.set_index('car name')

# Remove the 'origin' column
del car_data['origin']

car_data.sort_values(by = 'acceleration', ascending = True).head(10)
# Out:
#                           mpg  cylinders  displacement horsepower  weight  \
# car name
# plymouth 'cuda 340       14.0          8         340.0        160    3609
# plymouth fury iii        14.0          8         440.0        215    4312
# amc ambassador dpl       15.0          8         390.0        190    3850
# chevrolet impala         14.0          8         454.0        220    4354
# pontiac grand prix       16.0          8         400.0        230    4278
# chevrolet monte carlo    15.0          8         400.0        150    3761
# dodge challenger se      15.0          8         383.0        170    3563
# ford galaxie 500         15.0          8         429.0        198    4341
# pontiac catalina         14.0          8         455.0        225    4425
# buick estate wagon (sw)  14.0          8         455.0        225    3086
#
#                          acceleration  model year
# car name
# plymouth 'cuda 340                8.0          70
# plymouth fury iii                 8.5          70
# amc ambassador dpl                8.5          70
# chevrolet impala                  9.0          70
# pontiac grand prix                9.5          73
# chevrolet monte carlo             9.5          70
# dodge challenger se              10.0          70
# ford galaxie 500                 10.0          70
# pontiac catalina                 10.0          70
# buick estate wagon (sw)          10.0          70

# %%
# Create a scatter plot which compares displace to horsepower iwth the size being model year
plt.figure(figsize=(20,10))

plt.scatter(car_data['horsepower'],
            car_data['acceleration'],
            c="red", edgecolor="black", marker="o",
            alpha=0.8, label="acceleration")

plt.title("Acceleration Vs. Horsepower")
plt.ylabel("Acceleration")
plt.xlabel("Horsepower")
plt.xticks(np.arange(5,250,10))
plt.yticks(np.arange(6,20,0.5))
plt.grid(True)

plt.show()
